# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3,7,8])
ypoints = np.array([4,8,9])

plt.plot(xpoints, ypoints, marker='D', mec='cyan', mfc='cyan', ls='-.', c='r', linewidth='3.14')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330]) 

font1 = {'family':'serif', 'color':'brown', 'size': 20}
font2 = {'family':'serif', 'color':'red', 'size': 15}

plt.title("Sports Watch Data", fontdict= font1)
plt.xlabel("Average Pulse", fontdict= font2)
plt.ylabel("Calorie Burnage", fontdict= font2)

plt.grid(ls='--', color='red', lw='0.5')
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([34,12,8,43])
lables = ('Aryan', 'Poshak', 'Gita', 'Lekhnath')
explode = (0.2,0,0,0)

plt.pie(x, labels=lables, explode=explode, shadow = True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 9
#       6 explode = (0.2,0,0,0)
#       8 plt.pie(x, labels=lables, explode=explode, shadow = True)
# ----> 9 plt.legends()
#      10 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'legends'

# %%
import matplotlib.pyplot as plt
class Circle(object):
    
    # Constructor
    def __init__(self, radius=3, color='blue'):
        self.radius = radius
        self.color = color 
    
    # Method
    def add_radius(self, r):
        self.radius = self.radius + r
        return(self.radius)
    
    # Method
    def drawCircle(self):
        plt.gca().add_patch(plt.Circle((0, 0), radius=self.radius, fc=self.color))
        plt.axis('scaled')
        plt.show()
